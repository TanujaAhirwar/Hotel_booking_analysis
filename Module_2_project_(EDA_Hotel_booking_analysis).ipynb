# %% [markdown]
# <a href="https://colab.research.google.com/github/TanujaAhirwar/Hotel_booking_analysis/blob/main/Module_2_project_(EDA_Hotel_booking_analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA Hotel Booking Analysis
# ##### **Contribution**    - Individual
# ##### **Team Member 1 - Tanuja Ahirwar**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The purpose of this hotel booking study was to examine a hotel's customer data and look for any possible patterns or correlations. This exploratory data analysis's (EDA) goal was to examine the hotel booking data set and find any possible connections between important variables.
#
# Booking information for customers was included in the data set. Descriptive statistics were computed for every variable as part of the investigation, and visuals were made to examine the connections between different variables. We created a number of charts, including as count plots, bar plots, kdeplots, heatmaps,  to extract information from the dataset.
#
# Booking information for customers was included in the data set. Descriptive statistics were computed for every variable as part of the investigation, and visuals were made to examine the connections between different variables. In order to gain understanding from the parameters "arrival_date_year," "arrival_date_month," "arrival_date_week_number," "arrival_date_day_of_month," and "stays_in_weeknights" 'adults', 'children', 'babies','meal', 'country','market_segment', 'distribution_channel', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled','reserved_room_type', 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent', 'company', 'days_in_waiting_list', 'customer_type', 'adr','required_car_parking_spaces', 'total_of_special_requests','reservation_status', and'reservation_status_date'.
#
# The object, float64, and int64 datatypes are used for dataset variables. There are 32 variables total: 16 int64, 4 float64, and 12 objects. Duplicate values from 31994 were eliminated. The variables' null values were as follows: children had 4, agent had 12193, and corporation had 82137. We substituted the null value with the mode of each variable (country, children, agent) for these variables, but the variable "company" had more than 50% null value, so we eliminated it. We also eliminated anomalies from the lead_time and adr fields.
#
# Additionally, we modified the data types of the variables reservation_status_date, children, and agent to datetime64, int64, and int64, respectively. We performed some feature engineering for additional convenience and generated new variables: total_stays, total_people, total_childrens, reserved_room_assigned, guest_category, and lead_time_category. We converted total_people and total_childrens to int64 since they were previously in the floating 64 datatype. Now We were deleted from the observation because having total_people at 0 made no sense.

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions!
# This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data.
# Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing essential liberies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset

df = pd.read_csv('/content/drive/MyDrive/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(f' We have  {df.shape[0]} rows and {df.shape[1]} columns.')
# Out:
#  We have  119390 rows and 32 columns.

# %%
# Exploring descriptive statistical parameter
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %%
# Exploring column of the datasets
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# Information on records for hotel stays by clients is included in this dataset. More precisely, it provides reservation details for both city hotels and resort hotels. Among other things, it includes the date of the reservation, the duration of the stay, the number of adults, kids, and/or infants, and the number of parking spaces that are available. We just looked at a few of these variables in order to write this essay.

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 31994

# %%
#Removing of duplicate values
#df.drop_duplicates()

# %%
#checking new shape of dataset
df.shape
# Out:
# (119390, 32)

# %% [markdown]
# data has 31994 duplicate values

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values
plt.figure(figsize=(25,12))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='Accent')
plt.xlabel('Columns')
plt.title('Missing Values Places')
# Out:
# Text(0.5, 1.0, 'Missing Values Places')

# %%
#replacing null value with 0.0
null_columns= ['agent','children','company']
for col in null_columns:
  df[col].fillna(0.0,inplace=True)

#Repacing NA value in country by others
df['country'].fillna('others',inplace=True)

# %%
# Reassurance of any null value present in the database
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          0
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# company                           0
# days_in_waiting_list              0
# ...

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains information on records for client stays at hotels. precisely, booking details for both city hotels and resort hotels, including the date of the the booking, the duration of the stay, the number of adults, children, and/or infants, and the quantity of parking spaces that are available, among other details. Only a few of these variables were examined for the purposes of this piece.
#
# Also dataset contains 31994 duplicate values and some missing value in country, agent and company column.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# There are 19 numerical variables
# ['is_canceled', 'lead_time', 'arrival_date_year', 'arrival_date_week_number', 'arrival_date_day_of_month', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults', 'children', 'babies', 'is_repeated_guest', 'previous_cancellations', 'previous_bookings_not_canceled', 'booking_changes', 'agent', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']
# There are 19 numerical variables.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns:
    print(f'{i}:{df[i].unique()}')
    print('__'*50)
# Out:
# hotel:['Resort Hotel' 'City Hotel']
# ____________________________________________________________________________________________________
# is_canceled:[0 1]
# ____________________________________________________________________________________________________
# lead_time:[342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
#covert float type to int
df = df.astype({"children":'int', "agent":'int', "company":'int' })
# converting object type to datetime
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'], format = '%Y-%m-%d')
#check for NA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  int64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The variables "children," "agent," "company,"do not have the correct datatype format. So they are transformed from float64 datatypes to int64.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1
# Countries according to Ten largest values of guest
guest_according_country = df[df['is_canceled']==0]['country'].value_counts().reset_index()
guest_according_country.columns = ['country','no of guests']
guest_according_country=guest_according_country.nlargest(35, ['no of guests'])

plt.figure(figsize=(18,8))
sns.barplot(x=guest_according_country['country'],y=guest_according_country['no of guests'],order=guest_according_country['country'])
plt.xlabel('Country Name')
plt.ylabel('No of Guests')
plt.title("Guests Accourding to country")
# Out:
# Text(0.5, 1.0, 'Guests Accourding to country')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# knowing the countries from which most guests originate because
# is vital for businesses to optimize their operations, marketing efforts, and overall customer experience. It enables them to create a more welcoming and accommodating environment, ultimately contributing to the success and sustainability of the business.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Herontries from where coming most of guest are PRT, GBR & FRA.e

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Understanding the origin of most guests can be crucial for businesses in various sectors, particularly those in the tourism and hospitality industry. Here's why it is important:
#
# 1.Targeted Marketing:
#
# Knowing the primary countries from which most guests come allows businesses to tailor their marketing strategies to effectively reach and attract individuals from those specific regions. This may involve using targeted advertising, language preferences, or cultural nuances to appeal to the identified demographic
#
# 2.Cultural Sensitivity:
#
# Different cultures have unique preferences and expectations when it comes to products and services.
#
# 3.Language Considerations:
# 4.Product and Service Adaptation:
#
# Businesses can adapt their products and services based on the preferences of guests from specific countries. This might include offering cuisine options, entertainment choices, or amenities that are more likely to appeal to visitors from those regions.
#
# 5.Networking and Partnerships:
#
# Knowledge of the primary countries of origin for guests can facilitate strategic partnerships and collaborations with businesses in those regions.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Plotting the count plot for arrivals per month
plt.figure(figsize = (12,10), dpi=110)
sns.countplot(x = 'arrival_date_month', data = df, order = df['arrival_date_month'].value_counts().index)
plt.title('Arrival per Month', weight='bold')
plt.xlabel('Arrival Month')
plt.ylabel('No. of Count')
# Out:
# Text(0, 0.5, 'No. of Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  insights derived from the analysis of arrival patterns, businesses can align their strategies and operations with customer demand, leading to increased revenue, improved customer satisfaction, and overall positive business impact.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We may infer from this graph of Arrival Month and Count that August has the highest customer rate, followed by July, May, October, and so on. January has the lowest customer rate.
#
# January may be the greatest month of the year to reserve a hotel stay because it has the fewest reservations. Due to fewer demand of rooms, the cost for room on daily basis also minimum compared to other months when month of August has high demand for room therefore it is obvious that the cost of room is also at peak.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# 1.Strategic Pricing:
# Understanding the seasonal patterns allows businesses to implement dynamic pricing strategies. During high-demand months like August, prices can be adjusted upwards, maximizing revenue. Conversely, during low-demand months like January, businesses can offer promotions and lower prices to attract more customers.
#
# 2.Optimized Marketing:
# Knowing the peak and off-peak seasons enables businesses to allocate marketing resources more efficiently. During low-demand months, marketing efforts can be intensified to attract customers with special promotions, discounts, or packages.
#
# 3.Resource Allocation:
# Businesses can optimize their operational resources based on demand fluctuations.
#
# 4.Customer Experience:
# During periods of lower demand, businesses can focus on enhancing the customer experience without the pressures of high occupancy. This might involve staff training, renovations, or improvements to amenities, contributing to positive customer reviews and loyalty.
#
#
# 5.Promotional Campaigns:
# Promotional campaigns can be strategically timed based on demand trends.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Plotting the count plot for arrivals per month on different types of hotel
plt.figure(figsize = (12,10), dpi=110)
sns.countplot(x = 'arrival_date_month', data = df, hue ='hotel', order = df['arrival_date_month'].value_counts().index)
plt.title('Arrival per Month')
plt.legend(title='Type of Hotel')
plt.xlabel('Arrival Month')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analize the Hotel choosing pattern of the customers and demand of both the type of hotels resorts and city hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The number of bookings made each month is shown in the graph above.
# The graph indicates that August is the busiest month.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1.Strategic Pricing: Understanding the seasonal patterns allows businesses to implement dynamic pricing strategies.
# 2.Optimized Marketing: Knowing the peak and off-peak seasons enables businesses to allocate marketing resources more efficiently.
#
# 3.Resource Allocation: Businesses can optimize their operational resources based on demand fluctuations.
#
# 4.Customer Experience:
#
# 5.Promotional Campaigns:

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#catogaries for booking, 0 for booking  not canceled; 1 for booking cancelled
catogaries_of_booking_canceled = df.is_canceled.unique()
print(catogaries_of_booking_canceled)
# Out:
# [0 1]

# %%
#replace 0 by Not canceled & 1 by canceled
df.is_canceled = df.is_canceled.replace(0,'Not_Canceled').replace(1, 'Canceled')

# %%
df.groupby('is_canceled').size().plot(kind='pie', labels=["Bookings Canceled", "Bookings Not Canceled"], fontsize=15, autopct='%.2f%%',  figsize=(6, 6))
plt.ylabel('' )
plt.title('Bookings Cancelation')
# Out:
# Text(0.5, 1.0, 'Bookings Cancelation')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understanding the cancellation rates provides businesses  that can be used to refine strategies, enhance customer satisfaction, and optimize operational efficiency.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight that 37.02% of bookings were canceled and 62.98% were not canceled provides valuable information that can help businesses create a positive impact.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1.Cancellation Policies: Understanding the cancellation rate allows businesses to review and optimize their cancellation policies.
#
# 2.Businesses can use this information to implement revenue management strategies. By analyzing patterns in cancellations, they can adjust pricing or offer promotions during periods with higher cancellation rates to attract more bookings and minimize revenue loss.
#
# 3.Customer Retention:Focusing on the reasons for cancellations can help businesses identify areas for improvement. By addressing common issues leading to cancellations, such as customer dissatisfaction or changes in plans, businesses can work towards improving customer retention.
#
# 4.Operational Efficiency:
# Businesses can adjust staffing levels, inventory, and other resources based on expected booking patterns to optimize operational efficiency.
#
#
# 5.Enhanced Customer Communication:
# Effective communication with customers can play a crucial role in reducing cancellations. Businesses can implement proactive communication strategies, such as reminder emails or personalized offers, to keep customers engaged and encourage them to fulfill their bookings.
#
# 6.Financial Planning:
# Knowing the cancellation rate helps in financial planning. Businesses can allocate resources more effectively by considering potential revenue fluctuations associated with cancellations, allowing for better budgeting and financial stability.
#
# 7.Technology and Tools:
# Utilizing advanced reservation systems and analytics tools can help businesses better predict and manage cancellations. These tools can provide real-time insights, allowing businesses to adjust strategies promptly.
#
# 8.Customer Feedback and Improvement:

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#Highest booking made by agents
highest_bookings= df.groupby(['agent'])['agent'].agg({'count'}).reset_index().sort_values(by='count',ascending=False)


# Droping agent NAN value.it having no booking
highest_bookings.drop(highest_bookings[highest_bookings['agent']==0].index,inplace=True)

#Top ten agent having highest booking
top_agent =  highest_bookings[:10]

top_agent
# Out:
#      agent  count
# 9        9  31961
# 174    240  13922
# 1        1   7191
# 14      14   3640
# 7        7   3539
# 6        6   3290
# 183    250   2870
# 175    241   1721
# 27      28   1666
# 8        8   1514

# %%
#Visualizaing the graph

plt.figure(figsize=(18,8))
sns.barplot(x=top_agent['agent'],y=top_agent['count'],order=top_agent['agent'])
plt.xlabel('Agent No')
plt.ylabel('Number of Bookings')
plt.title("Bookings Made by the agent")
# Out:
# Text(0.5, 1.0, 'Bookings Made by the agent')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to Identifying the top agents  who make the highest number of bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight that agents numbered 9, 240, and 1 make the highest number of bookings is valuable information for a business,

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1.Performance Recognition and Motivation
# Recognizing the achievements of agents 9, 240, and 1 can boost morale and motivation within the team. Acknowledging their success, perhaps through incentives or public recognition, can inspire other agents to strive for excellence, fostering a positive and competitive work environment.
#
# 2.Training and Knowledge Transfer:
# Analyzing the strategies and practices of the top-performing agents can provide valuable insights for training programs.
#
# 3.Optimizing Sales Strategies:
# Studying the successful approaches of agents 9, 240, and 1 can help in optimizing sales strategies.
#
# 4.Resource Allocation and Workload Distribution:
#
#
# 5.Setting Performance Benchmarks:
#
# 6.Strategic Planning:
# The success of specific agents can influence strategic planning. Businesses may consider expanding their sales force, replicating successful strategies in other regions, or tailoring their marketing efforts based on the success of these top agents.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Plot the graph of number of nights people wants to stay against total number of bookings
nights_stays = (df['stays_in_weekend_nights']+ df['stays_in_week_nights']).value_counts().head(10).sort_index()
nights_stays.plot.bar(color='green')
plt.rcParams['figure.figsize'] = (10,5)
plt.title('Duration of Night stay')
plt.ylabel('Total number of bookings')
plt.xlabel('Number of nights')
# Out:
# Text(0.5, 0, 'Number of nights')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  Gaining insights about customer stay preferences and optimal lengths of stay

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The majority of guests want to stay for one, two, three, or four nights, however the demand for reservations for stays of two and three nights is stronger than for stays of any other length.
# When analyzing the ideal duration for obtaining the best daily rate, we find that stays of two to four days can be more economical because this is what most people prefer. Additionally, hotels offer mid-term accommodations because long-term stays will fill up their rooms, making it impossible for new guests to book accommodations and possibly preventing them from making additional money.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1.Pricing Strategies:
# Understanding that there is a higher demand for two and three nights allows businesses to implement dynamic pricing strategies.
#
# 2.Promotional Offers:
# Based on the insight that more customers prefer stays of two to four nights, hotels can design targeted promotional offers for these durations.
#
# 3.Revenue Optimization:
# By offering more attractive rates for mid-length stays, hotels can optimize revenue. This approach encourages customers to choose longer stays, maximizing room occupancy and revenue potential without compromising on room availability for new customers.
#
# 4.Marketing Strategies:
# Marketing efforts can be tailored to highlight the benefits of mid-length stays.
#
# 5.Occupancy Management:
# Analyzing the optimal length of stay helps in managing room occupancy effectively.
#
# 6.Customer Loyalty Programs:
#
# Hotels can incorporate the optimal stay duration into their loyalty programs.
#
# 7.Operational Efficiency:
#
# 8.Competitive Advantage:
#
# 9.Customer Satisfaction:

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# Observing peoples interest to stay according to hotel type with graph
df.loc[:,'total_nights'] = df['stays_in_weekend_nights']+ df['stays_in_week_nights']

fig, ax = plt.subplots(figsize=(12,6))
sns.countplot(x='total_nights', hue='hotel', data=df, order = df.total_nights.value_counts().iloc[:10].index)
ax.set_title('Hotel wise night stay duration')
ax.set_xlabel('No of Nights')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  to gained  the visual representation of customer preferences for city hotels and resort hotels based on the length of stay

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# People are interested in staying in city hotels for two, three, one, and four days, respectively, according to this visual representation, while people are interested in staying in resort hotels for one, seven, two, and three days, respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# For City Hotels:
# 1.Pricing Strategies:
# City hotels can implement dynamic pricing strategies, offering competitive rates for popular durations (two, three days).
#
# 2.Promotional Packages:
# Designing promotional packages specifically for two and three-night stays can appeal to the preferences revealed in the visual representation. Bundle deals, discounts, or added amenities for these durations can attract more bookings.
#
# 3.Business Traveler Focus:
#
# If two and three-night stays are popular, city hotels can tailor their services to cater to business travelers who often have shorter stays. Offering business-friendly amenities and services can enhance the hotel's appeal to this demographic.
#
# 4.Optimized Operational Planning:
#  This includes staffing levels, housekeeping schedules, and other operational aspects to align with the booking patterns.
#
#
# For Resort Hotels:
# 1.Seasonal Promotions:
# Resort hotels can create seasonal promotions catering to the preference for one, seven, two, and three-night stays. For example, offering special packages during the seven-night stay period might attract longer-term vacationers.
#
# 2.Extended Stay Benefits:
#
# Since longer stays are popular for resort hotels, they can offer added benefits for guests staying seven nights or more.
#
# 3.Event and Activity Planning:
#
# Resorts can plan events, activities, and themed experiences for guests staying seven nights or longer. This can enhance the overall guest experience and encourage longer bookings.
#
#
# 4.Strategic Partnerships:
# Building partnerships with travel agencies or tour operators for longer-term vacation packages can expand the reach of resort hotels

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Percentage distribution of repeated guests
df['is_repeated_guest'].value_counts(normalize=True) * 100
# Out:
# is_repeated_guest
# 0    96.808778
# 1     3.191222
# Name: proportion, dtype: float64

# %%
# Plotting the graph showing the count of customers for different hotel whether they are repeated guest or not
plt.figure(figsize = (8,6), dpi=110)
sns.countplot(x = 'is_repeated_guest', data = df, hue ='hotel',  palette='Paired')
plt.title('customer who repeated their bookings')
plt.legend(title='Hotel Type')
plt.xlabel('Repeated Guest (0 = No, 1 = Yes)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# understanding the distribution of regular and new customers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights derived from the graph, where only around 3.2% of customers are identified as regulars and approximately 96.8% are new customers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# 1.Customer Loyalty Focus-
# Recognizing the low percentage of regular customers, businesses can place a heightened focus on customer loyalty initiatives.
#
# 2.Enhanced Customer Retention Strategies-
# The data suggests an opportunity to improve customer retention.
#
# 3.Feedback Utilization-
# Regular customers can provide valuable insights into what works well and what could be improved.
#
# Negative Business Impact:
# 1.Customer Acquisition Cost Optimization-
# Acknowledging the high percentage of new customers, businesses can work on optimizing customer acquisition costs. Targeted marketing, efficient onboarding processes, and strategic partnerships can contribute to acquiring new customers more cost-effectively.
#
# 2.Onboarding Excellence:
# Since a significant portion of customers are new, businesses can focus on providing an excellent onboarding experience. Clear communication, user-friendly interfaces, and introductory offers can facilitate positive initial interactions.
#
# 3.Data-Driven Decision-Making:
#
# Utilizing data on regular and new customers allows businesses to make informed decisions. Analyzing customer behavior, preferences, and feedback can guide product/service improvements, marketing strategies, and overall business optimization.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
# Distribution of customers across various market segments
market_seg_customers = df['market_segment'].value_counts(normalize = True) * 100
market_seg_customers
# Out:
# market_segment
# Online TA        47.304632
# Offline TA/TO    20.285619
# Groups           16.593517
# Direct           10.558673
# Corporate         4.435045
# Complementary     0.622330
# Aviation          0.198509
# Undefined         0.001675
# Name: proportion, dtype: float64

# %%
# Plotting market segments with total number of customers
plt.rcParams['figure.figsize'] = (15, 5)
market_seg_customers.plot(kind='line',marker='o')
plt.grid()
plt.title('Total number of bookings in different market segments')
plt.ylabel('Total number of bookings')
plt.xlabel('Market Segment')
# Out:
# Text(0.5, 0, 'Market Segment')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Finding the Percentage Distribution of customers across various market segments

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight that the Online Travel Agency (OTA) segment provides a high number of customers, followed by Offline Travel Agencies/Tour Operators (TA/TO), Groups, and Direct bookings etc.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Online TA (Travel Agency) Segment-
#
# Given the high number of customers from online travel agencies, businesses can allocate more resources to digital marketing strategies. This may include targeted online advertising, search engine optimization (SEO), and social media marketing to capitalize on the online market.
#
#
# Offline TA/TO Segment-
#
# Recognizing the significance of Offline TA/TO, businesses can tailor marketing strategies for this segment. This may include traditional advertising methods, participation in travel fairs, and building relationships with offline travel agencies.
# Personalized Engagement with Offline Partners:
#
#
# Groups and Direct Bookings-
# Group-Focused Marketing Strategies:
#
# For the Groups segment, businesses can design specific marketing strategies to attract group bookings. Offering group discounts, customized packages, and facilitating easy coordination can make the business more appealing to group travelers.
#
# Direct Booking Incentives:
#
# Recognizing that direct bookings contribute to customer acquisition, businesses can provide incentives for customers to book directly. This may include special discounts, loyalty program benefits, or exclusive perks available only for direct bookings.
# Enhanced Customer Service for Direct Bookings:

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Plotting the graph showing the count of Customer booking their reservation through various market segment and checking whether they have cancelled thier reservation or not
plt.figure(figsize = (12,6), dpi=110)
sns.countplot(x = 'market_segment', data = df, hue = 'is_canceled',  order = df['market_segment'].value_counts().index)
plt.title('Market Segment Types', weight='bold')
plt.xlabel('Market Segment')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the relationship between market segment and cancellation

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The group segment has a cancellation rate of over 50%.
# The cancellation rate for both online and offline travel agents and tour operators, or TA/TO, is more than 33%.
# The graph shows that the cancellation rate in the Direct Segment is less than 20%.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 Reservations in different type of hotels
ax = df['hotel'].value_counts().plot.pie(explode=[0.05, 0.05], autopct='%1.1f%%', shadow=True, figsize=(10,8),fontsize=16, colors=['tab:green', 'tab:red'])
ax.set_title('% share of different hotel type ',fontsize = 18, fontweight='bold')
# Out:
# Text(0.5, 1.0, '% share of different hotel type ')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the tyoe of hotels preffered by the guest

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most popular hotels among visitors are city hotels. As a result, city hotels are fully booked.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# 1. Targeted Marketing Strategies: Companies can concentrate their marketing efforts on advertising their city hotel assets since they know that city hotels are in great demand. This could entail specialized marketing initiatives directed towards business travelers or city dwellers on a regular basis.
# 2. Optimized Pricing Strategies: Businesses can adjust their pricing strategies to reflect the high demand for city hotels. This could involve implementing dynamic pricing models to capitalize on peak booking periods or offering attractive deals and packages to encourage bookings during slower periods.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 Hotel price distribution.
hotel_price = df.groupby('hotel')['adr'].mean().astype(int).reset_index()

sns.set(rc={'figure.figsize':(8,8)})
sns.set_palette("Set1")
graph = sns.barplot(x='hotel',y='adr', data=hotel_price)
graph.set_title('Hotel price distribution',fontsize = 16, fontweight='bold')
graph.set_xlabel('Hotel Type',fontsize = 14)
graph.set_ylabel('Avg Daily Price',fontsize = 14)
# Out:
# Text(0, 0.5, 'Avg Daily Price')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To find the correlation between the price of the Hotels

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This graph shows that the approximate daily rate (ADR) of city hotels is more than that of resort hotels (about 80 against 100).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Revenue Optimization: Companies can enhance their revenue management tactics by realizing that metropolitan hotels fetch a higher average daily rate. In order to optimize revenue potential, particularly during peak seasons or periods of strong demand, they can modify pricing accordingly.
# Marketing and positioning: This information can help with marketing plans that emphasize the benefits of staying at city hotels, like their accessibility to major cities, convenience, and facilities. By highlighting the higher ADR in comparison to resort hotels, you can draw in customers who value luxury and are prepared to pay more for upscale lodging.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 Analysis based on Repeated Guest
df['is_repeated_guest'].value_counts().plot.pie(explode=[0.05]*2, autopct='%.0f%%', figsize=(10,8),fontsize=20)
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=df['is_repeated_guest'].value_counts().index.tolist())
plt.title('% of repeated customers in Hotel',fontsize = 16, fontweight='bold')
# Out:
# Text(0.5, 1.0, '% of repeated customers in Hotel')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To Analysis Guest behaviour if they prefer there last stay

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Mostly the guests are new customers and very small share for repeated customers

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Focused Marketing Strategies: Businesses can focus their marketing efforts on drawing in and converting new guests by keeping in mind that the majority of visitors are potential consumers. To draw in potential new customers, this may entail running focused marketing campaigns, promotions, and exclusive deals.
# Enhanced Customer Acquisition: Companies should give top priority to programs like alliances with online travel agencies (OTAs), corporate clients, and travel agents that are designed to bring in new business. Through increasing their exposure and reach, they may draw a constant flow of new visitors to their sites.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code


plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), cmap= 'coolwarm' ,annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-7c58386221cd> in <cell line: 5>()
#       3
#       4 plt.figure(figsize=(20,20))
# ----> 5 sns.heatmap(df.corr(), cmap= 'coolwarm' ,annot=True)
#       6 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
fig, axes = plt.subplots(1,2, figsize=(26, 8))

sns.set(rc={'figure.figsize':(18,8)})
sns.set_palette("husl")
graph = sns.countplot(ax=axes[0],x="meal",hue='hotel', data=df)
graph.set_title('different customer type Prefernce meal',fontsize = 16)
graph.set_xlabel('Type of Meal',fontsize = 14)
graph.set_ylabel('No. of People',fontsize = 14)

ax=axes[1],df['meal'].value_counts().plot.pie(explode=[0.05]*5, autopct='%.0f%%', figsize=(15,8),fontsize=18,pctdistance=1.1,labeldistance=1.3,labels=None)
plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=df['meal'].value_counts().index.tolist())
plt.title('% share for preference of meal for customers',fontsize = 16)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analysed meal preference of the customers

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 77% of respondents said they prefer bed and breakfast (BB) meals in both types of hotels.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The finding that 77% of consumers prefer bed and breakfast (BB) meals in both types of hotels can have a favorable effect on business, particularly for companies in the hospitality sector. Businesses can potentially increase customer satisfaction and loyalty by customizing their services to match the preferences of their customers by having a better understanding of those preferences. In order to draw in more customers, hotels that provide bed and breakfast packages might use this information to promote their options more strongly, change their price policies, or improve the quality of their breakfast services.

# %% [markdown]
# # **OBSERVATION **

# %% [markdown]
# ~ Due to the lower ADR, most consumers favor City hotels and A-room types.
# ~ Resort hotels are more expensive than City hotels since they receive twice as many bookings, but the revenue differential is smaller.
# ~ The best months to book a resort hotel are October through April, while the best months to book a city hotel are November through March because ADR is lower during this time.
#
# ~August is the month when the most reservations and cancellations occur.
# ~ Between June and September, both types of hotels see an increase in revenue because ADR is also high during this time.
# ~ 2016 saw the most reservations and cancellations for hotels.
# ~ Annually, 25–30% of resort hotels and 40–45% of metropolitan hotels experience cancellations.
# ~ ADR falls with longer lead times. This implies that a consumer can receive a hotel room at a discounted rate if he books it in advance.
# ~ ADR falls when overall stay duration rises. This implies that patrons can receive a better value for extended stays.
# ~ For shorter stays, people favor city hotels, whereas for longer stays, they favor resort hotels.
# ~ Hotels with refund policies are more expensive than those without; the former are less expensive.
# ~ The majority of reservations are made by sporadic clientele.
# ~ Customers who are transient cancel more frequently, although group booking results in fewer cancellations.
# ~ The majority of reservations and cancellations are handled by online and offline travel companies and tour operators.
# ~ In comparison to resort hotels, there are more cancellations in city hotels.
# ~ When hotels do not collect deposits, there is a greater likelihood of cancellation.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# ~ The majority of consumers like A-rooms, so in order to boost revenue, hotels should provide more of these.
# ~ In order to reduce the probability of cancellation, hotels should require a minimum deposit as there is a high likelihood of cancellation when no deposit is received.
# ~ In order to reduce cancellations, hotels should give some sort of incentive.
# ~ While group reservations result in fewer cancellations than single reservations, transient customers cancel more frequently.
# ~ The months of May through August see the highest amount of bookings, therefore hotels can entice guests with compelling deals to book more nights during the off-season.
# ~ Hotels' management should pay attention to customer input and make improvements to the hotel's amenities in order to boost the number of returning visitors, as the number of repeat business is declining.
# ~ Portugal, France, and the United Kingdom are the western European nations that send us the most tourists and also bring in the most money. To attract more clients, marketing departments must to focus on these nations.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
